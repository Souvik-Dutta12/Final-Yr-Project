# %%
import pandas as pd

# %%
data = r"C:\Users\debas\OneDrive\Desktop\Final Year Project\Main_prj\new ds\crop_recomendation\prev_data.csv"

# %%
df = pd.read_csv(data)

# %%
df
# Out:
#           _id      id       year   state_name  state_code   district_name  \
# 0        9901    9900  1997-1998  West Bengal          19         Bankura
# 1        9902    9901  1997-1998  West Bengal          19         Bankura
# 2        9903    9902  1997-1998  West Bengal          19         Bankura
# 3        9904    9903  1997-1998  West Bengal          19         Bankura
# 4        9905    9904  1997-1998  West Bengal          19         Bankura
# ...       ...     ...        ...          ...         ...             ...
# 16084  455355  455354  2022-2023  West Bengal          19  Uttar Dinajpur
# 16085  455356  455355  2022-2023  West Bengal          19  Uttar Dinajpur
# 16086  455357  455356  2022-2023  West Bengal          19  Uttar Dinajpur
# 16087  455358  455357  2022-2023  West Bengal          19  Uttar Dinajpur
# 16088  455359  455358  2022-2023  West Bengal          19  Uttar Dinajpur
#
#        district_code     crop_name  crop_code crop_type      season     area  \
# ...

# %%
df_filtered = df[df['year'].isin(['2021-2022', '2022-2023'])]

# %%
df_filtered
# Out:
#           _id      id       year   state_name  state_code   district_name  \
# 14807  432870  432869  2021-2022  West Bengal          19      Alipurduar
# 14808  432871  432870  2021-2022  West Bengal          19      Alipurduar
# 14809  432872  432871  2021-2022  West Bengal          19      Alipurduar
# 14810  432873  432872  2021-2022  West Bengal          19      Alipurduar
# 14811  432874  432873  2021-2022  West Bengal          19      Alipurduar
# ...       ...     ...        ...          ...         ...             ...
# 16084  455355  455354  2022-2023  West Bengal          19  Uttar Dinajpur
# 16085  455356  455355  2022-2023  West Bengal          19  Uttar Dinajpur
# 16086  455357  455356  2022-2023  West Bengal          19  Uttar Dinajpur
# 16087  455358  455357  2022-2023  West Bengal          19  Uttar Dinajpur
# 16088  455359  455358  2022-2023  West Bengal          19  Uttar Dinajpur
#
#        district_code  crop_name  crop_code crop_type  season     area  \
# ...

# %%
df_filtered["district_name"].unique()
# Out:
# <StringArray>
# [       'Alipurduar',           'Bankura',           'Birbhum',
#        'Cooch Behar',  'Dakshin Dinajpur',        'Darjeeling',
#            'Hooghly',            'Howrah',        'Jalpaiguri',
#           'Jhargram',         'Kalimpong',             'Malda',
#        'Murshidabad',             'Nadia', 'North 24 Parganas',
#  'Paschim Bardhaman', 'Paschim Medinipur',   'Purba Bardhaman',
#    'Purba Medinipur',           'Purulia', 'South 24 Parganas',
#     'Uttar Dinajpur']
# Length: 22, dtype: str

# %%
df_filtered["crop_name"].unique()
# Out:
# <StringArray>
# [            'Arhar/Tur',                  'Gram',             'Groundnut',
#             'Horse-Gram',                  'Jute',               'Khesari',
#                'Linseed',                 'Maize',                'Masoor',
#                  'Mesta',     'Moong(Green Gram)',            'Niger Seed',
#  'Peas & Beans (Pulses)',                'Potato',     'Rapeseed &Mustard',
#                   'Rice',               'Sesamum',             'Sugarcane',
#                   'Urad',                 'Wheat',              'Sannhamp',
#          'Small Millets',             'Sunflower',                'Barley',
#    'Other Kharif Pulses',             'Safflower',              'Soyabean',
#                'Tobacco',                  'Ragi',                 'Jowar',
#      'Other Rabi Pulses',                 'Bajra',          'Cotton(Lint)']
# Length: 33, dtype: str

# %%
df_filtered.to_csv("filtered__prev_data.csv", index=False)
